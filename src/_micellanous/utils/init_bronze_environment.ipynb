# %%
# TABLES
source = json_config.get("sources").get(sources).get("bronze").get("orig_table")
bronze = json_config.get("sources").get(sources).get("bronze").get("dest_table")
bronze_full_table_name = f'{licenses_catalog}.{bronze}'

print(f'task of etl from {source} to {bronze_full_table_name}')

# %%
#SECRETS
token = json_config.get("env").get(env).get("secrets").get("api_token")
print(f'Api token was successfully recovered')
