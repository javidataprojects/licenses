# %%
# %run "./functions"

# %%
env = get_environment()
json_config = get_config_params()
print(json_config)

# %%
#CATALOGS

catalogs = json_config.get("env").get(env).get("catalogs")

licenses_catalog = catalogs.get("licenses")

for k, value in catalogs.items():
    print(f'Catalog available: {value} -> {k}_catalog ')
    k = catalogs.get(k)
